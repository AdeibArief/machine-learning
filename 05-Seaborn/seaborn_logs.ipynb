# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\adeeb\OneDrive\Desktop\python\machine learning course\05-Seaborn\dm_office_sales.csv')
df
# Out:
#               division  level of education  training level  work experience  \
# 0             printers        some college               2                6
# 1             printers  associate's degree               2               10
# 2          peripherals         high school               0                9
# 3      office supplies  associate's degree               2                5
# 4      office supplies         high school               1                5
# ..                 ...                 ...             ...              ...
# 995  computer hardware  associate's degree               1                1
# 996  computer software  associate's degree               1                0
# 997        peripherals  associate's degree               2                8
# 998        peripherals  associate's degree               2                3
# 999  computer hardware        some college               0                9
#
#      salary   sales
# 0     91684  372302
# ...

# %%
plt.figure(figsize=(12,5),dpi=100)
sns.scatterplot(data=df,x='salary',y='sales',hue='level of education',palette='Dark2',size='salary',s=200,alpha=1,style='level of education');

# %%
plt.figure(figsize=(8,4),dpi=100)
sns.scatterplot(data=df,x='salary',y='sales',hue='salary');

# %% [markdown]
# # Distribution plots

# %%
df=pd.read_csv("./dm_office_sales.csv")
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
sns.rugplot(x='salary',data=df,height=0.5)
# Out:
# <Axes: xlabel='salary'>

# %%
sns.displot(x='salary',data=df,color='red',edgecolor='black',linewidth=2)

# %%
sns.displot(x='salary',data=df,color='red',edgecolor='black',linewidth=2,kde=True)

# %% [markdown]
# # categorical plot

# %%
np.random.seed(42)
sample_values=np.random.randint(0,100,200)
sample_values
# Out:
# array([51, 92, 14, 71, 60, 20, 82, 86, 74, 74, 87, 99, 23,  2, 21, 52,  1,
#        87, 29, 37,  1, 63, 59, 20, 32, 75, 57, 21, 88, 48, 90, 58, 41, 91,
#        59, 79, 14, 61, 61, 46, 61, 50, 54, 63,  2, 50,  6, 20, 72, 38, 17,
#         3, 88, 59, 13,  8, 89, 52,  1, 83, 91, 59, 70, 43,  7, 46, 34, 77,
#        80, 35, 49,  3,  1,  5, 53,  3, 53, 92, 62, 17, 89, 43, 33, 73, 61,
#        99, 13, 94, 47, 14, 71, 77, 86, 61, 39, 84, 79, 81, 52, 23, 25, 88,
#        59, 40, 28, 14, 44, 64, 88, 70,  8, 87,  0,  7, 87, 62, 10, 80,  7,
#        34, 34, 32,  4, 40, 27,  6, 72, 71, 11, 33, 32, 47, 22, 61, 87, 36,
#        98, 43, 85, 90, 34, 64, 98, 46, 77,  2,  0,  4, 89, 13, 26,  8, 78,
#        14, 89, 41, 76, 50, 62, 95, 51, 95,  3, 93, 22, 14, 42, 28, 35, 12,
#        31, 70, 58, 85, 27, 65, 41, 44, 61, 56,  5, 27, 27, 43, 83, 29, 61,
#        74, 91, 88, 61, 96,  0, 26, 61, 76,  2, 69, 71, 26])

# %%
sample_values=pd.DataFrame(sample_values,columns=['age'])
sample_values
# Out:
#      age
# 0     51
# 1     92
# 2     14
# 3     71
# 4     60
# ..   ...
# 195   76
# 196    2
# 197   69
# 198   71
# 199   26
#
# [200 rows x 1 columns]

# %%
sns.rugplot(data=sample_values,x='age')
# Out:
# <Axes: xlabel='age'>

# %%
sns.displot(data=sample_values,x='age',kde=True)

# %%
sns.kdeplot(data=sample_values,x='age')
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.kdeplot(data=sample_values,x='age',clip=(0,100),bw_adjust=2,shade=True)
# Out:
# C:\Users\adeeb\AppData\Local\Temp\ipykernel_13940\4150512425.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=sample_values,x='age',clip=(0,100),bw_adjust=2,shade=True)
# <Axes: xlabel='age', ylabel='Density'>

# %%
plt.figure(figsize=(10,6),dpi=100)
sns.countplot(data=df,x='division')
# Out:
# <Axes: xlabel='division', ylabel='count'>

# %%
plt.figure(figsize=(10,6),dpi=100)
sns.countplot(data=df,x='level of education')
# Out:
# <Axes: xlabel='level of education', ylabel='count'>

# %%
plt.figure(figsize=(10,6),dpi=100)
sns.countplot(data=df,x='level of education',hue='division',palette='twilight')
# Out:
# <Axes: xlabel='level of education', ylabel='count'>

# %%
# sns.barplot(data=df,x='level of education',y='division',estimator=np.mean,ci='SD')
sns.barplot(x='level of education',y='salary',data=df,estimator=np.mean,errorbar='sd',hue='division')
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 2
#       1 # sns.barplot(data=df,x='level of education',y='division',estimator=np.mean,ci='SD')
# ----> 2 sns.barplot(x='level of education',y='salary',data=df,estimator=np.mean,errorbar='sd',hue='division')
#       3 plt.tight_layout()
#
# File c:\Users\adeeb\OneDrive\Desktop\python\machine learning course\venv\Lib\site-packages\seaborn\categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2752 if estimator is len:
#    2753     estimator = "size"
# -> 2755 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                       estimator, errorbar, n_boot, units, seed,
#    2757                       orient, color, palette, saturation,
# ...

# %% [markdown]
# # Categorical plots

# %%
df=pd.read_csv("./StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
plt.figure(figsize=(10,4))
sns.boxplot(data=df,x='reading score',y='parental level of education',hue='test preparation course')
# Out:
# <Axes: xlabel='reading score', ylabel='parental level of education'>

# %%
plt.figure(figsize=(10,4))
sns.violinplot(data=df,x='reading score',y='parental level of education',inner='quartile',bw=0.5)
# Out:
# <Axes: xlabel='reading score', ylabel='parental level of education'>

# %%
sns.swarmplot(data=df,x='math score',y='gender',size=2,hue='test preparation course',dodge=True)
# Out:
# <Axes: xlabel='math score', ylabel='gender'>

# %%
df=pd.read_csv('StudentsPerformance.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
sns.jointplot(x='math score',y='reading score',data=df,kind='kde',hue='gender',shade='True')
# Out:
# c:\Users\adeeb\OneDrive\Desktop\python\machine learning course\venv\Lib\site-packages\seaborn\axisgrid.py:1826: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=self.x, y=self.y, **kwargs)

# %%
sns.pairplot(data=df,hue='gender')

# %%
sns.catplot(data=df,x='gender',y='math score',kind='violin',col='lunch',row='race/ethnicity')

# %%
g=sns.PairGrid(df,hue='gender')
g.map_upper(sns.kdeplot)
g.map_diag(sns.kdeplot)
g.map_lower(sns.scatterplot)
g.add_legend()

# %%
df=pd.read_csv('country_table.csv')
df
# Out:
#                          Countries  Birth rate  Mortality rate  \
# 0                           AFRICA      32.577           7.837
# 1                             ASIA      15.796           7.030
# 2                           EUROPE      10.118          11.163
# 3  LATIN AMERICA AND THE CARIBBEAN      15.886           6.444
# 4                 NORTHERN AMERICA      11.780           8.833
# 5                          OCEANIA      16.235           6.788
# 6                            WORLD      17.963           7.601
#
#    Life expectancy  Infant mortality rate  Growth rate
# 0           63.472                 44.215        24.40
# 1           73.787                 23.185         8.44
# 2           78.740                  3.750         0.38
# 3           75.649                 14.570         8.89
# 4           79.269                  5.563         6.11
# 5           78.880                 16.939        12.79
# 6           72.766                 27.492        10.36

# %%
df=df.set_index('Countries')

# %%
df
# Out:
#                                  Birth rate  Mortality rate  Life expectancy  \
# Countries
# AFRICA                               32.577           7.837           63.472
# ASIA                                 15.796           7.030           73.787
# EUROPE                               10.118          11.163           78.740
# LATIN AMERICA AND THE CARIBBEAN      15.886           6.444           75.649
# NORTHERN AMERICA                     11.780           8.833           79.269
# OCEANIA                              16.235           6.788           78.880
# WORLD                                17.963           7.601           72.766
#
#                                  Infant mortality rate  Growth rate
# Countries
# AFRICA                                          44.215        24.40
# ASIA                                            23.185         8.44
# EUROPE                                           3.750         0.38
# ...

# %%
sns.heatmap(df)
# Out:
# <Axes: ylabel='Countries'>

# %%
rates = df.drop('Life expectancy',axis=1)

# %%
sns.heatmap(rates,cmap='viridis',annot=True)
# Out:
# <Axes: ylabel='Countries'>

# %%
sns.clustermap(rates)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 sns.clustermap(rates)
#
# File c:\Users\adeeb\OneDrive\Desktop\python\machine learning course\venv\Lib\site-packages\seaborn\matrix.py:1250, in clustermap(data, pivot_kws, method, metric, z_score, standard_scale, figsize, cbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, row_colors, col_colors, mask, dendrogram_ratio, colors_ratio, cbar_pos, tree_kws, **kwargs)
#    1157 """
#    1158 Plot a matrix dataset as a hierarchically-clustered heatmap.
#    1159
#    (...)
#    1247
#    1248 """
#    1249 if _no_scipy:
# -> 1250     raise RuntimeError("clustermap requires scipy to be available")
#    1252 plotter = ClusterGrid(data, pivot_kws=pivot_kws, figsize=figsize,
#    1253                       row_colors=row_colors, col_colors=col_colors,
# ...
