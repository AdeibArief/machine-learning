# %% [markdown]
# # Dragon real estate

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('data.csv')
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df['CHAS'].value_counts()
# Out:
# 0    471
# 1     35
# Name: CHAS, dtype: int64

# %%
sns.countplot(df)
# Out:
# <Axes: ylabel='count'>

# %%
sns.histplot(bins=50,data=df['CHAS'])
# Out:
# <Axes: xlabel='CHAS', ylabel='Count'>

# %%
df.hist()

# %%
from sklearn.model_selection import train_test_split

# %%
train_set,test_set = train_test_split(df, test_size=0.2, random_state=42)

# %%
df.corr()['CRIM']
# Out:
# CRIM       1.000000
# ZN        -0.200469
# INDUS      0.406583
# CHAS      -0.055892
# NOX        0.420972
# RM        -0.219433
# AGE        0.352734
# DIS       -0.379670
# RAD        0.625505
# TAX        0.582764
# PTRATIO    0.289946
# B         -0.385064
# LSTAT      0.455621
# MEDV      -0.388305
# Name: CRIM, dtype: float64

# %%
corr_matrix=df.corr().sort_values(by='CRIM',ascending=True)

# %%
corr_matrix
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# MEDV    -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.696169 -0.376955
# B       -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128107 -0.273534
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.203507 -0.747881
# RM      -0.219433  0.311173 -0.394193  0.091468 -0.302751  1.000000 -0.240286
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311173 -0.569537
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091468  0.086518
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.357612  0.261515
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240286  1.000000
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.394193  0.644779
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302751  0.731470
# LSTAT    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.615721  0.602339
# ...

# %%
sns.scatterplot(data=df,x='RM',y='MEDV')
# Out:
# <Axes: xlabel='RM', ylabel='MEDV'>

# %%
df['TAXRM']=df['TAX']/df['RM']

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV      TAXRM
# 0       15.3  396.90   4.98  24.0  45.019011
# ...

# %%
df.corr()['MEDV']
# Out:
# CRIM      -0.388305
# ZN         0.360445
# INDUS     -0.483725
# CHAS       0.175260
# NOX       -0.427321
# RM         0.696169
# AGE       -0.376955
# DIS        0.249929
# RAD       -0.381626
# TAX       -0.468536
# PTRATIO   -0.507787
# B          0.333461
# LSTAT     -0.737663
# MEDV       1.000000
# TAXRM     -0.540380
# Name: MEDV, dtype: float64

# %%
sns.scatterplot(data=df,x='TAXRM',y='MEDV')
# Out:
# <Axes: xlabel='TAXRM', ylabel='MEDV'>

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
split=StratifiedShuffleSplit()
for train_index,test_index in split.split(df,df['CHAS']):
    strat_train_set=df.loc[train_index]
    strat_test_set=df.loc[test_index]

# %%
# Out:
# (51, 15)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
scaled_train_set=scaler.fit_transform(train_set)
# scaled_test_set

# %%
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline

# %%
imputer=SimpleImputer()
imputer.fit(df)
X=imputer.transform(df)

# %%
df_tr=pd.DataFrame(X)

# %%
pipe=Pipeline([
    ('imputer',SimpleImputer(strategy='median')),
    ('scaler',StandardScaler()), # Standardize the data. This is not necessary for Decision Trees, but it's good practice to do       
])

# %%
df_num_tr=pipe.fit_transform(df_tr)
df_num_tr
# Out:
# array([[-0.41978194,  0.28482986, -1.2879095 , ..., -1.0755623 ,
#          0.15968566, -0.70010018],
#        [-0.41733926, -0.48772236, -0.59338101, ..., -0.49243937,
#         -0.10152429, -0.93456481],
#        [-0.41734159, -0.48772236, -0.59338101, ..., -1.2087274 ,
#          1.32424667, -1.06275126],
#        ...,
#        [-0.41344658, -0.48772236,  0.11573841, ..., -0.98304761,
#          0.14880191, -0.88833383],
#        [-0.40776407, -0.48772236,  0.11573841, ..., -0.86530163,
#         -0.0579893 , -0.85480142],
#        [-0.41500016, -0.48772236,  0.11573841, ..., -0.66905833,
#         -1.15724782, -0.69195584]])

# %% [markdown]
# # Select machine learning model
